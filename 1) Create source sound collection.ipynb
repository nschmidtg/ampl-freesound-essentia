# %% [markdown]
# # 1) Create source sound collection
#
# This notebook includes the code to create the collection of sounds that will later be used as source material for our audio mosaicing application. The collection of sounds is created by defining a number of queries to be performed using the Freesound API and concatenanting the results of each query. A number of metadata fields are stored for each sound in the collection and saved into a Pandas DataFrame object and CSV file in disk. For each sound in the collection, we also download an OGG preview and store it in disk.
#
# This notebook uses the `freesound` Python package for interacting with the Freesound API. The source code for this package can be found here: https://github.com/mtg/freesound-python. In this repository you'll find a Python script with [examples](https://github.com/MTG/freesound-python/blob/master/examples.py) to learn how to interact with the API. Nevertheless, if you are further interested in the Freesound API, check the [API documentation](http://freesound.org/docs/api/) which provides more information.
#
# **NOTE**: A Freesound API key is provided in this notebook, but you should make a Freesound account and get your own key. You can get a key here: https://freesound.org/apiv2/apply/

# %%
import os
import pandas as pd
import numpy as np
import freesound
from IPython.display import display

FREESOUND_API_KEY = ''  # Please replace by your own Freesound API key
FILES_DIR = 'files'  # Place where to store the downloaded diles. Will be relative to the current folder.
DATAFRAME_FILENAME = 'dataframe.csv'  # File where we'll store the metadata of our sounds collection
FREESOUND_STORE_METADATA_FIELDS = ['id', 'name', 'username', 'previews', 'license', 'tags']  # Freesound metadata properties to store

freesound_client = freesound.FreesoundClient()
freesound_client.set_token(FREESOUND_API_KEY)
if not os.path.exists(FILES_DIR): os.mkdir(FILES_DIR)

# %%
# Define some util functions

def query_freesound(query, filter, num_results=10):
    """Queries freesound with the given query and filter values.
    If no filter is given, a default filter is added to only get sounds shorter than 30 seconds.
    """
    if filter is None:
        filter = 'duration:[0 TO 30]'  # Set default filter
    pager = freesound_client.text_search(
        query = query,
        filter = filter,
        fields = ','.join(FREESOUND_STORE_METADATA_FIELDS),
        group_by_pack = 1,
        page_size = num_results
    )
    return [sound for sound in pager]

def retrieve_sound_preview(sound, directory):
    """Download the high-quality OGG sound preview of a given Freesound sound object to the given directory.
    """
    return freesound.FSRequest.retrieve(
        sound.previews.preview_hq_ogg,
        freesound_client,
        os.path.join(directory, sound.previews.preview_hq_ogg.split('/')[-1])
    )

def make_pandas_record(sound):
    """Create a dictionary with the metadata that we want to store for each sound.
    """
    record = {key: sound.as_dict()[key] for key in FREESOUND_STORE_METADATA_FIELDS}
    del record['previews']  # Don't store previews dict in record
    record['freesound_id'] = record['id']  # Rename 'id' to 'freesound_id'
    del record['id']
    record['path'] = "files/" + sound.previews.preview_hq_ogg.split("/")[-1]  # Store path of downloaded file
    return record

# %%
# Build our collection of sounds

# Our collection of sounds is made by appending the results of a number of different queries to freesound
# The query terms, query filters and the number of results per query are all defined here.
# Information about how to define filters can be found in the Freesound API documentation: https://freesound.org/docs/api/resources_apiv2.html#request-parameters-text-search-parameters
freesound_queries = [
    {
        'query': 'dog bark',
        'filter': None,
        'num_results': 20, 
    },
    {
        'query': 'percussion sounds',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
    {
        'query': 'vocals',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
    {
        'query': 'kick',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
    {
        'query': 'snare',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
    {
        'query': 'hihat',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
]

# Do all queries and concatenate the results in a single list of sounds
sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

# Download the sounds and save them to FILES_DIR folder
for count, sound in enumerate(sounds):
    print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
    retrieve_sound_preview(sound, 'files/')
    
# Make a Pandas DataFrame with the metadata of our sound collection and save it
df =  pd.DataFrame([make_pandas_record(s) for s in sounds])
df.to_csv(DATAFRAME_FILENAME)
print('Saved DataFrame with {0} entries! {1}'.format(len(df), DATAFRAME_FILENAME))

# Show the contents of our DataFrame (the metadata of our source collection)
display(df)
# Out:
# Downloading sound with id 337101 [1/120]
# Downloading sound with id 327666 [2/120]
# Downloading sound with id 518570 [3/120]
# Downloading sound with id 413758 [4/120]
# Downloading sound with id 163459 [5/120]
# Downloading sound with id 456943 [6/120]
# Downloading sound with id 418105 [7/120]
# Downloading sound with id 236042 [8/120]
# Downloading sound with id 115536 [9/120]
# Downloading sound with id 160093 [10/120]
# Downloading sound with id 180977 [11/120]
# Downloading sound with id 485962 [12/120]
# Downloading sound with id 157322 [13/120]
# Downloading sound with id 118963 [14/120]
# Downloading sound with id 501678 [15/120]
# Downloading sound with id 425904 [16/120]
# Downloading sound with id 464400 [17/120]
# Downloading sound with id 386766 [18/120]
# Downloading sound with id 533826 [19/120]
# Downloading sound with id 199261 [20/120]
# Downloading sound with id 124103 [21/120]
# Downloading sound with id 57040 [22/120]
# Downloading sound with id 463937 [23/120]
# Downloading sound with id 260469 [24/120]
# Downloading sound with id 183115 [25/120]
# Downloading sound with id 338748 [26/120]
# Downloading sound with id 463936 [27/120]
# Downloading sound with id 463938 [28/120]
# Downloading sound with id 207919 [29/120]
# Downloading sound with id 424373 [30/120]
# Downloading sound with id 264173 [31/120]
# Downloading sound with id 566595 [32/120]
# Downloading sound with id 31061 [33/120]
# Downloading sound with id 249977 [34/120]
# Downloading sound with id 473252 [35/120]
# Downloading sound with id 562334 [36/120]
# Downloading sound with id 193978 [37/120]
# Downloading sound with id 139500 [38/120]
# Downloading sound with id 535779 [39/120]
# Downloading sound with id 111163 [40/120]
# Downloading sound with id 315688 [41/120]
# Downloading sound with id 75511 [42/120]
# Downloading sound with id 464633 [43/120]
# Downloading sound with id 464634 [44/120]
# Downloading sound with id 490702 [45/120]
# Downloading sound with id 464636 [46/120]
# Downloading sound with id 464635 [47/120]
# Downloading sound with id 432883 [48/120]
# Downloading sound with id 87649 [49/120]
# Downloading sound with id 272029 [50/120]
# Downloading sound with id 556422 [51/120]
# Downloading sound with id 510014 [52/120]
# Downloading sound with id 520894 [53/120]
# Downloading sound with id 88159 [54/120]
# Downloading sound with id 251689 [55/120]
# Downloading sound with id 88402 [56/120]
# Downloading sound with id 417506 [57/120]
# Downloading sound with id 150505 [58/120]
# Downloading sound with id 166161 [59/120]
# Downloading sound with id 180349 [60/120]
# Downloading sound with id 520616 [61/120]
# Downloading sound with id 344759 [62/120]
# Downloading sound with id 171104 [63/120]
# Downloading sound with id 215441 [64/120]
# Downloading sound with id 183098 [65/120]
# Downloading sound with id 42030 [66/120]
# Downloading sound with id 148634 [67/120]
# Downloading sound with id 255533 [68/120]
# Downloading sound with id 250547 [69/120]
# Downloading sound with id 264601 [70/120]
# Downloading sound with id 40614 [71/120]
# Downloading sound with id 259994 [72/120]
# Downloading sound with id 106290 [73/120]
# Downloading sound with id 131336 [74/120]
# Downloading sound with id 509983 [75/120]
# Downloading sound with id 368648 [76/120]
# Downloading sound with id 189174 [77/120]
# Downloading sound with id 347077 [78/120]
# Downloading sound with id 330041 [79/120]
# Downloading sound with id 89187 [80/120]
# Downloading sound with id 543497 [81/120]
# Downloading sound with id 270156 [82/120]
# Downloading sound with id 212208 [83/120]
# Downloading sound with id 387186 [84/120]
# Downloading sound with id 100395 [85/120]
# Downloading sound with id 524886 [86/120]
# Downloading sound with id 25663 [87/120]
# Downloading sound with id 495777 [88/120]
# Downloading sound with id 131362 [89/120]
# Downloading sound with id 510044 [90/120]
# Downloading sound with id 35587 [91/120]
# Downloading sound with id 13750 [92/120]
# Downloading sound with id 335921 [93/120]
# Downloading sound with id 34829 [94/120]
# Downloading sound with id 207929 [95/120]
# Downloading sound with id 160857 [96/120]
# Downloading sound with id 165209 [97/120]
# Downloading sound with id 188116 [98/120]
# Downloading sound with id 47698 [99/120]
# Downloading sound with id 73038 [100/120]
# Downloading sound with id 524880 [101/120]
# Downloading sound with id 207905 [102/120]
# Downloading sound with id 207914 [103/120]
# Downloading sound with id 509970 [104/120]
# Downloading sound with id 44943 [105/120]
# Downloading sound with id 46152 [106/120]
# Downloading sound with id 13246 [107/120]
# Downloading sound with id 165321 [108/120]
# Downloading sound with id 448223 [109/120]
# Downloading sound with id 102780 [110/120]
# Downloading sound with id 387473 [111/120]
# Downloading sound with id 548453 [112/120]
# Downloading sound with id 78219 [113/120]
# Downloading sound with id 193521 [114/120]
# Downloading sound with id 137778 [115/120]
# Downloading sound with id 199808 [116/120]
# Downloading sound with id 185033 [117/120]
# Downloading sound with id 515925 [118/120]
# Downloading sound with id 361267 [119/120]
# Downloading sound with id 135390 [120/120]
# Saved DataFrame with 120 entries! dataframe.csv
#      freesound_id                                            license  \
# 0          337101  http://creativecommons.org/publicdomain/zero/1.0/
# 1          327666     http://creativecommons.org/licenses/by-nc/3.0/
# 2          518570        http://creativecommons.org/licenses/by/3.0/
# 3          413758  http://creativecommons.org/publicdomain/zero/1.0/
# 4          163459  http://creativecommons.org/publicdomain/zero/1.0/
# 5          456943  http://creativecommons.org/publicdomain/zero/1.0/
# 6          418105        http://creativecommons.org/licenses/by/3.0/
# 7          236042     http://creativecommons.org/licenses/by-nc/3.0/
# 8          115536        http://creativecommons.org/licenses/by/3.0/
# 9          160093        http://creativecommons.org/licenses/by/3.0/
# 10         180977  http://creativecommons.org/publicdomain/zero/1.0/
# 11         485962  http://creativecommons.org/publicdomain/zero/1.0/
# 12         157322        http://creativecommons.org/licenses/by/3.0/
# 13         118963  http://creativecommons.org/publicdomain/zero/1.0/
# 14         501678     http://creativecommons.org/licenses/by-nc/3.0/
# 15         425904  http://creativecommons.org/publicdomain/zero/1.0/
# 16         464400  http://creativecommons.org/publicdomain/zero/1.0/
# 17         386766  http://creativecommons.org/publicdomain/zero/1.0/
# 18         533826  http://creativecommons.org/publicdomain/zero/1.0/
# 19         199261  http://creativecommons.org/publicdomain/zero/1.0/
# 20         124103  http://creativecommons.org/publicdomain/zero/1.0/
# 21          57040        http://creativecommons.org/licenses/by/3.0/
# 22         463937  http://creativecommons.org/publicdomain/zero/1.0/
# 23         260469  http://creativecommons.org/publicdomain/zero/1.0/
# 24         183115        http://creativecommons.org/licenses/by/3.0/
# 25         338748  http://creativecommons.org/publicdomain/zero/1.0/
# 26         463936  http://creativecommons.org/publicdomain/zero/1.0/
# 27         463938        http://creativecommons.org/licenses/by/3.0/
# 28         207919        http://creativecommons.org/licenses/by/3.0/
# 29         424373  http://creativecommons.org/publicdomain/zero/1.0/
# ..            ...                                                ...
# 90          35587        http://creativecommons.org/licenses/by/3.0/
# 91          13750  http://creativecommons.org/publicdomain/zero/1.0/
# 92         335921  http://creativecommons.org/publicdomain/zero/1.0/
# 93          34829        http://creativecommons.org/licenses/by/3.0/
# 94         207929        http://creativecommons.org/licenses/by/3.0/
# 95         160857  http://creativecommons.org/publicdomain/zero/1.0/
# 96         165209  http://creativecommons.org/publicdomain/zero/1.0/
# 97         188116        http://creativecommons.org/licenses/by/3.0/
# 98          47698  http://creativecommons.org/publicdomain/zero/1.0/
# 99          73038  http://creativecommons.org/publicdomain/zero/1.0/
# 100        524880  http://creativecommons.org/publicdomain/zero/1.0/
# 101        207905        http://creativecommons.org/licenses/by/3.0/
# 102        207914        http://creativecommons.org/licenses/by/3.0/
# 103        509970  http://creativecommons.org/publicdomain/zero/1.0/
# 104         44943        http://creativecommons.org/licenses/by/3.0/
# 105         46152        http://creativecommons.org/licenses/by/3.0/
# 106         13246        http://creativecommons.org/licenses/by/3.0/
# 107        165321  http://creativecommons.org/publicdomain/zero/1.0/
# 108        448223  http://creativecommons.org/publicdomain/zero/1.0/
# 109        102780        http://creativecommons.org/licenses/by/3.0/
# 110        387473        http://creativecommons.org/licenses/by/3.0/
# 111        548453        http://creativecommons.org/licenses/by/3.0/
# 112         78219        http://creativecommons.org/licenses/by/3.0/
# 113        193521        http://creativecommons.org/licenses/by/3.0/
# 114        137778  http://creativecommons.org/publicdomain/zero/1.0/
# 115        199808  http://creativecommons.org/publicdomain/zero/1.0/
# 116        185033        http://creativecommons.org/licenses/by/3.0/
# 117        515925        http://creativecommons.org/licenses/by/3.0/
# 118        361267  http://creativecommons.org/publicdomain/zero/1.0/
# 119        135390        http://creativecommons.org/licenses/by/3.0/
#
#                                          name                          path  \
# 0                   Group_of_Dogs_Barking.WAV   files/337101_3474310-hq.ogg
# 1                                Dog Bark.wav   files/327666_5632380-hq.ogg
# 2                            Barking Dogs.wav  files/518570_10201334-hq.ogg
# 3                              dogbarking.mp3   files/413758_7958399-hq.ogg
# 4          LBS_FX DOG Small Alert Bark001.wav   files/163459_2965892-hq.ogg
# 5                 Blossom Bark  29sec mix.wav   files/456943_3194431-hq.ogg
# 6                           single dog bark 3   files/418105_6078577-hq.ogg
# 7          Jazz the Dog Howl & Bark (027).wav    files/236042_180659-hq.ogg
# 8                               Two Barks.wav   files/115536_1956076-hq.ogg
# 9                                  Dog bark 2   files/160093_2888453-hq.ogg
# 10                                Barking Dog   files/180977_3370987-hq.ogg
# 11               Dog Barking Distance - 1.wav   files/485962_6150892-hq.ogg
# 12         Dog Bark Staffordshire Bullterrier        files/157322_58-hq.ogg
# 13                             Dog Bark 3.wav   files/118963_1990695-hq.ogg
# 14                            BARKING DOG.wav   files/501678_9610234-hq.ogg
# 15                                 BarkingDog   files/425904_8563244-hq.ogg
# 16                               Dog_Bark.wav   files/464400_7372230-hq.ogg
# 17                            Dog_Barking.wav   files/386766_5768130-hq.ogg
# 18                               Dog Bark.wav  files/533826_11852214-hq.ogg
# 19            A dog barking (close recording)   files/199261_1661766-hq.ogg
# 20                                K Sound.wav   files/124103_2219481-hq.ogg
# 21                         suctioncupkick.wav       files/57040_4948-hq.ogg
# 22                               Lighter Fire   files/463937_9754348-hq.ogg
# 23         electribe-kicks slice 09 [A-4].wav   files/260469_2127539-hq.ogg
# 24                           prc_appet909.wav   files/183115_2394245-hq.ogg
# 25   Perc. coffee tin 03 muted March 2016.wav   files/338748_5450487-hq.ogg
# 26                          Small Case Closed   files/463936_9754348-hq.ogg
# 27                                 Velcro Rip   files/463938_9754348-hq.ogg
# 28                                Space snare     files/207919_19852-hq.ogg
# 29                     percussion sound 1.wav   files/424373_7099958-hq.ogg
# ..                                        ...                           ...
# 90                           IMPACT SNARE.wav     files/35587_113878-hq.ogg
# 91                                snare 2.aif      files/13750_32468-hq.ogg
# 92                  Xtrullor Snare 04 [E].wav   files/335921_1317013-hq.ogg
# 93                            Low_snare_1.wav     files/34829_209299-hq.ogg
# 94                                    Snare 1     files/207929_19852-hq.ogg
# 95                         heavy snare 25.wav   files/160857_2262092-hq.ogg
# 96                         Rpeople_Snare1.wav   files/165209_2997898-hq.ogg
# 97                                snare14.wav     files/188116_19852-hq.ogg
# 98                            paper snare.wav     files/47698_102620-hq.ogg
# 99                                A Snare.wav    files/73038_1061526-hq.ogg
# 100                               Hihat 7.wav  files/524880_11502075-hq.ogg
# 101                      Evolver closed hihat     files/207905_19852-hq.ogg
# 102                              open hihat 2     files/207914_19852-hq.ogg
# 103                       Hi-Hat Closed 4.mp3   files/509970_8033171-hq.ogg
# 104                    Hihat CL C3000B-07.wav     files/44943_236326-hq.ogg
# 105                      Hihat CL SM58-04.wav     files/46152_236326-hq.ogg
# 106                          hihat closed.aif      files/13246_36719-hq.ogg
# 107                            Echoed Hi-Hats   files/165321_3008343-hq.ogg
# 108                      Hip Hop Closed Hihat   files/448223_7020227-hq.ogg
# 109                acoustic_closed_hihat1.wav    files/102780_480691-hq.ogg
# 110                          HiHat_1_mono.wav     files/387473_97763-hq.ogg
# 111                   BBeats Air HiHat 04.wav    files/548453_861714-hq.ogg
# 112                                HiHat5.wav     files/78219_747245-hq.ogg
# 113                          Open hihat 5.wav   files/193521_2172430-hq.ogg
# 114                               weird_hihat   files/137778_1684206-hq.ogg
# 115                               Junk hi-hat   files/199808_3491501-hq.ogg
# 116                              Reso (hihat)   files/185033_3429866-hq.ogg
# 117                          Bitcrushed Hihat   files/515925_4772988-hq.ogg
# 118                         8-bit Soft Hi-Hat   files/361267_2901280-hq.ogg
# 119                               HiHat02.wav   files/135390_2452753-hq.ogg
#
#                                                   tags            username
# 0    [growling, growl, Group, barking, animal, pet,...             ivolipa
# 1    [bellow, barking, intimidating, angrily, bark,...   Juan_Merie_Venter
# 2    [Ferrell-dogs, guarding-dog, doggie-daycare, H...           Astounded
# 3                       [big, bark, dog, Dog, barking]       lala_davis554
# 4               [Chihuahua, FX, Dog, dog, Small, bark]     LittleBigSounds
# 5     [German-shepherd, barking, Dog, dog, bark, howl]             Zajjman
# 6    [growling, growl, barking, pet, dog, animal, b...         crazymonke9
# 7    [Barking, Jazz, Barks, Dog, Howling, Wolf, Ani...       delphidebrain
# 8    [animal, bark, barking, dog, effects, noise, s...              Puniho
# 9                            [Average-size, bark, dog]         jorickhoofd
# 10                   [bark, happy, loud, dog, barking]         Suprasummun
# 11   [distance, barking, dog, woof, attack, backgro...            SpaceJoe
# 12   [sennheiser, sound-devices, dog, m-s, stafford...               Anton
# 13                                 [animal, bark, dog]             esperri
# 14                           [bark, owi, dog, barking]      tsakanemashaba
# 15                       [InterSpecies2018, bark, dog]          NatalieTre
# 16                                 [Bark, Dog, Animal]    michael_grinnell
# 17                                [bark, dog, barking]              ken788
# 18                                 [bark, Dog, Animal]           Angellu16
# 19   [moan, blume, barking, usa, grunting, felix, d...         felix.blume
# 20   [beatboxing, connersaw8, mouth, percussion, so...          connersaw8
# 21     [dangerous, foley, kitchen, percussion, sounds]      NoiseCollector
# 22   [152, random, Percussion, Flint, Lighter, Stri...           RicardoRG
# 23   [bd, groovebox, presets, drum, bassdrum, percu...         soneproject
# 24   [perc, hits, drums, house, Percussion, music, ...                DWSD
# 25   [sample-pack, sampling, sample, raw, Sampler, ...         cabled_mess
# 26   [Sound, Music152, Drum, Garcia, Percussion, 15...           RicardoRG
# 27   [sound, 152, Drum, Garcia, Random, Percussion,...           RicardoRG
# 28    [percussion, imposcar, softsynth, snare, gforce]            altemark
# 29               [perc, percussion, percs, percussive]             Elnosos
# ..                                                 ...                 ...
# 90         [bass, dnb, drum, fat, hits, jungle, snare]               VEXST
# 91                                      [clean, snare]            hookhead
# 92                              [snare, drum, dubstep]             Tr4ck3r
# 93          [drums, hit, live, recording, snap, snare]               -zin-
# 94                      [imposcar, PWM, snare, gforce]            altemark
# 95   [heavy, drum-and-bass, house, dubstep, snare, ...            duskstep
# 96                                  [hit, snare, drum]        rhythmpeople
# 97       [distortion, casio, vz-10m, pd, phase, snare]            altemark
# 98                               [crunchy, old, snare]            jarryd19
# 99                                             [snare]             stenen1
# 100                               [Sound, Hihat, Drum]      TheCoolManARM2
# 101  [evolver, hihat, smith, metallic, dave, closed...            altemark
# 102  [hihat, softsynth, percussion, imposcar, open,...            altemark
# 103  [hihat, drum, drums, beat, closed-hat, sample,...         blakengouda
# 104  [acoustic, dance, drum, electro, hihat, hit, p...     Sascha Burghard
# 105  [acoustic, dance, drum, electro, hihat, hit, p...     Sascha Burghard
# 106                                    [closed, hihat]             ianhall
# 107                              [hihat, echo, hi-hat]           ani_music
# 108  [hip, Hihat, closed, drums, percussion, hop, hat]  ToxicFilmzSRsounds
# 109                 [acoustic-drum-kit, closed, hihat]                 mhc
# 110                    [lofi, mono, beatboxing, hihat]            AlienXXX
# 111          [beatbox, percussion, hiss, vocal, hihat]        Department64
# 112                         [hihat, percusion, sample]                Spol
# 113            [Sample, Hihat, Wav, Livedrums, Record]         datwilightz
# 114   [hihat, drum, closed-hihat, cymbal, hi-hat, hat]                skxr
# 115           [hihat, junk, scrap, drums, hi-hat, hat]          TheMinkman
# 116              [hihat, hi-hat, drum, drum-synthesis]           casmarrav
# 117  [Hihat, Crush, Drums, EDM, Sample, Percussion,...               EX-AN
# 118  [chiptune, chip, 8bit, famicom, electronic, im...  JapanYoshiTheGamer
# 119          [Cymbal, HiHat, Drum, Percussion, closed]        Bassmonkey91
#
# [120 rows x 6 columns]
